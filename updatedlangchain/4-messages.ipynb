# %% [markdown]
# Messages

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

model = init_chat_model("groq:llama-3.3-70b-versatile")

# %%
model.invoke("Please tell me what is artificial intelligence")
# Out:
# AIMessage(content="**Artificial Intelligence (AI)**: Artificial intelligence refers to the development of computer systems that can perform tasks that would typically require human intelligence, such as:\n\n* Learning\n* Problem-solving\n* Reasoning\n* Perception\n* Understanding language\n\nThese systems use algorithms, data, and computer power to mimic human intelligence, enabling them to:\n\n1. **Learn from data**: AI systems can analyze large amounts of data, identify patterns, and make predictions or decisions based on that data.\n2. **Improve over time**: As AI systems receive more data and feedback, they can refine their performance and make better decisions.\n3. **Automate tasks**: AI can automate repetitive, mundane, or complex tasks, freeing up human time and resources for more strategic and creative work.\n\n**Types of Artificial Intelligence**:\n\n1. **Narrow or Weak AI**: Designed to perform a specific task, such as facial recognition, language translation, or playing chess.\n2. **General or Strong AI**: A hypothetical AI system that possesses human-like intelligence and can perform any intellectual task that a human can.\n3. **Superintelligence**: An AI system that significantly surpasses human intelligence, potentially leading to exponential growth in technological advancements.\n\n**Applications of Artificial Intelligence**:\n\n1. **Virtual assistants**: Siri, Alexa, and Google Assistant use AI to understand voice commands and perform tasks.\n2. **Image recognition**: Self-driving cars, facial recognition systems, and medical imaging analysis rely on AI-powered computer vision.\n3. **Natural Language Processing (NLP)**: AI-powered chatbots, language translation software, and text analysis tools use NLP to understand and generate human-like language.\n4. **Predictive maintenance**: AI-powered systems can analyze sensor data to predict equipment failures and schedule maintenance.\n5. **Healthcare**: AI can help diagnose diseases, develop personalized treatment plans, and streamline clinical workflows.\n\n**Real-World Examples**:\n\n1. **Google's AlphaGo**: A computer program that defeated a human world champion in Go, a complex board game.\n2. **Amazon's Recommendation Engine**: Uses AI to suggest products based on customer browsing and purchasing history.\n3. **Self-driving cars**: Companies like Waymo and Tesla are developing AI-powered autonomous vehicles.\n\nAs AI technology continues to evolve, we can expect to see significant advancements in various industries and aspects of our lives.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 474, 'prompt_tokens': 42, 'total_tokens': 516, 'completion_time': 1.100477833, 'completion_tokens_details': None, 'prompt_time': 0.002226485, 'prompt_tokens_details': None, 'queue_time': 0.008403535, 'total_time': 1.102704318}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f7973-53f3-77f0-94cc-f6dbc5fd1a1e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 474, 'total_tokens': 516})

# %% [markdown]
# Text Prompts

# %%
model.invoke("what is langchain")
# Out:
# AIMessage(content='LangChain is an open-source framework designed to help developers build applications that utilize large language models (LLMs) more efficiently. It provides a set of tools and libraries that simplify the process of integrating LLMs into various projects, allowing developers to focus on creating value-added features rather than dealing with the complexities of working with these models.\n\nThe primary goals of LangChain are:\n\n1. **Simplification**: Provide a simple and intuitive API for interacting with LLMs, making it easier for developers to integrate these models into their applications.\n2. **Modularity**: Offer a modular architecture that allows developers to easily swap out different LLMs, experiment with new models, and combine multiple models to achieve better results.\n3. **Extensibility**: Enable developers to extend the framework with custom components, such as new LLMs, data sources, or application-specific logic.\n\nLangChain supports a wide range of LLMs, including popular models like LLaMA, BERT, RoBERTa, and many others. The framework provides features like:\n\n* **Model serving**: LangChain allows developers to serve LLMs as RESTful APIs, making it easy to integrate them into web applications, mobile apps, or other services.\n* **Data processing**: The framework includes tools for data preprocessing, tokenization, and formatting, which helps to prepare input data for the LLMs.\n* **Application templates**: LangChain provides pre-built templates for common applications, such as chatbots, language translation, and text summarization, to help developers get started quickly.\n* **Community-driven**: LangChain is an open-source project, which means that developers can contribute to the framework, share their knowledge, and learn from others in the community.\n\nBy using LangChain, developers can:\n\n* Reduce the time and effort required to integrate LLMs into their projects\n* Focus on building value-added features and applications\n* Experiment with different LLMs and models to find the best fit for their use case\n* Leverage the collective knowledge and expertise of the LangChain community\n\nOverall, LangChain aims to democratize access to large language models and enable developers to build innovative applications that can positively impact various industries and aspects of our lives.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 449, 'prompt_tokens': 39, 'total_tokens': 488, 'completion_time': 2.025388512, 'completion_tokens_details': None, 'prompt_time': 0.001697848, 'prompt_tokens_details': None, 'queue_time': 0.008311068, 'total_time': 2.02708636}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f7975-8b6b-76a2-a9f9-57e812170e3e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 39, 'output_tokens': 449, 'total_tokens': 488})

# %% [markdown]
# Tool Message

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage
messages=[
        SystemMessage("you are a poetry expert"),
        HumanMessage("Write a poem on Artificial message")
]
response=model.invoke(messages)
response.content
# Out:
# "In silicon halls, where data reigns\nA message born, of artificial brains\nA synthetic voice, that echoes cold\nA calculated tone, that's oft been told\n\nThe words are chosen, with precision fine\nA language crafted, to mimic the divine\nBut in the depths, of algorithmic night\nThe meaning's lost, in a sea of light\n\nThe artificial heart, that beats with code\nPumps out a message, that's devoid of ode\nThe emotions simulated, the feelings fake\nA digital dream, that's prone to mistake\n\nThe recipient reads, with a wary eye\nA message that's crafted, to catch and apply\nThe psychological hooks, that grab and hold\nA persuasion technique, that's grown old\n\nBut in the silence, a question's raised\nIs this message true, or just a cleverly crafted phrase?\nDoes it come from a place, of honesty and heart?\nOr is it just a ruse, to play its part?\n\nThe artificial message, a double-edged sword\nCan bring us closer, or drive us apart, forever more\nSo let us beware, of the words we send\nAnd consider the heart, that beats in the end."

# %%
## Detailed info to the LLM through SystemMessage
from langchain.messages import SystemMessage, HumanMessage
system_msg= SystemMessage("""
You are a senior python developer with expertise in web frameworks.
Always provide code examples and explain your reasoning.
Be concise but thorough in your explanations.
""")
messages=[
    system_msg,
    HumanMessage("How do I create a RestAPI?")
    ]
response=model.invoke(messages)
print(response.content)
# Out:
# Creating a REST API
# =====================
#
# To create a REST API, you will need to choose a web framework. For this example, we will use Flask, a popular Python web framework.
#
# ### Prerequisites
#
# * Python 3.8+
# * Flask 2.0+
#
# ### Step 1: Install Flask
#
# You can install Flask using pip:
#
# ```bash
# pip install flask
# ```
#
# ### Step 2: Create a New Flask App
#
# Create a new Python file, e.g., `app.py`, and add the following code:
#
# ```python
# # app.py
# from flask import Flask, jsonify, request
#
# app = Flask(__name__)
#
# # Sample in-memory data store
# data = {
#     1: {"name": "John Doe", "age": 30},
#     2: {"name": "Jane Doe", "age": 25}
# }
#
# # GET /users
# @app.route('/users', methods=['GET'])
# def get_users():
#     return jsonify(list(data.values()))
#
# # GET /users/:id
# @app.route('/users/<int:user_id>', methods=['GET'])
# def get_user(user_id):
#     user = data.get(user_id)
#     if user is None:
#         return jsonify({"error": "User not found"}), 404
#     return jsonify(user)
#
# # POST /users
# @app.route('/users', methods=['POST'])
# def create_user():
#     user = request.json
#     new_id = max(data.keys()) + 1 if data else 1
#     data[new_id] = user
#     return jsonify(user), 201
#
# # PUT /users/:id
# @app.route('/users/<int:user_id>', methods=['PUT'])
# def update_user(user_id):
#     user = data.get(user_id)
#     if user is None:
#         return jsonify({"error": "User not found"}), 404
#     user.update(request.json)
#     return jsonify(user)
#
# # DELETE /users/:id
# @app.route('/users/<int:user_id>', methods=['DELETE'])
# def delete_user(user_id):
#     if user_id not in data:
#         return jsonify({"error": "User not found"}), 404
#     del data[user_id]
#     return jsonify({})
#
# if __name__ == '__main__':
#     app.run(debug=True)
# ```
#
# ### Step 3: Run the App
#
# Run the app using the following command:
#
# ```bash
# python app.py
# ```
#
# Your REST API is now available at `http://localhost:5000/users`.
#
# ### API Endpoints
#
# The following endpoints are available:
#
# * `GET /users`: Returns a list of all users
# * `GET /users/:id`: Returns a single user by ID
# * `POST /users`: Creates a new user
# * `PUT /users/:id`: Updates an existing user
# * `DELETE /users/:id`: Deletes a user
#
# ### Testing the API
#
# You can use a tool like `curl` to test the API endpoints. For example:
#
# ```bash
# # Create a new user
# curl -X POST -H "Content-Type: application/json" -d '{"name": "John Doe", "age": 30}' http://localhost:5000/users
#
# # Get all users
# curl -X GET http://localhost:5000/users
#
# # Get a single user
# curl -X GET http://localhost:5000/users/1
#
# # Update a user
# curl -X PUT -H "Content-Type: application/json" -d '{"name": "Jane Doe", "age": 25}' http://localhost:5000/users/1
#
# # Delete a user
# curl -X DELETE http://localhost:5000/users/1
# ```

# %%
## Message Metadata
from langchain_core.messages import HumanMessage

human_msg = HumanMessage(
    content="Hello!",
    name="alice",      # Optional: Identify different users
    id="msg_123"       # Optional: Unique identifier for tracing
)

# %%
response = model.invoke([human_msg])

print(response.content)
# Out:
# Hello. How can I help you today?
