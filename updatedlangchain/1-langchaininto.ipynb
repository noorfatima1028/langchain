# %% [markdown]
# ### Langchain Version V1

# %%
import langchain
langchain.__version__
# Out:
# '1.3.14'

# %%
import os
from dotenv import load_dotenv

load_dotenv()

google_api_key = os.getenv("GOOGLE_API_KEY")
groq_api_key = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    api_key=groq_api_key
)

# %%
from langchain.agents import create_agent

agent = create_agent(
    model=llm,
    tools=[],
    system_prompt="You are a helpful assistant."
)

# %%
from langchain.tools import tool

@tool
def get_weather(city: str) -> str:
    """Get the current weather for a city."""
    return f"The weather in {city} is sunny."

# %%
agent = create_agent(
    model=llm,
    tools=[get_weather],
    system_prompt="You are a helpful assistant."
)

# %%
response = agent.invoke(
    {
        "messages": [
            ("user", "What is the weather in Lahore?")
        ]
    }
)

print(response["messages"][-1].content)
# Out:
# I've provided the information based on the function call. For the most recent and accurate weather, please refer to the function call result.

# %%
response["messages"]
# Out:
# [HumanMessage(content='What is the weather in Lahore?', additional_kwargs={}, response_metadata={}, id='4271d432-2442-44a8-b98d-324fde02b108'),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'ezrjz283z', 'function': {'arguments': '{"city":"Lahore"}', 'name': 'get_weather'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 227, 'total_tokens': 243, 'completion_time': 0.060512007, 'completion_tokens_details': None, 'prompt_time': 0.013308033, 'prompt_tokens_details': None, 'queue_time': 0.008279934, 'total_time': 0.07382004}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f7113-1d01-7363-bad4-f5ec3b17840a-0', tool_calls=[{'name': 'get_weather', 'args': {'city': 'Lahore'}, 'id': 'ezrjz283z', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 227, 'output_tokens': 16, 'total_tokens': 243}),
#  ToolMessage(content='The weather in Lahore is sunny.', name='get_weather', id='00d38ca7-6783-486a-b26a-e902657237ab', tool_call_id='ezrjz283z'),
#  AIMessage(content="I've provided the information based on the function call. For the most recent and accurate weather, please refer to the function call result.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 28, 'prompt_tokens': 260, 'total_tokens': 288, 'completion_time': 0.158610682, 'completion_tokens_details': None, 'prompt_time': 0.08494755, 'prompt_tokens_details': None, 'queue_time': 0.008458685, 'total_time': 0.243558232}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f7113-1e85-7583-afcd-4fb9be43dd28-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 260, 'output_tokens': 28, 'total_tokens': 288})]
